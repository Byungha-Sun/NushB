# %% [markdown]
# ## OPEN API 활용 : 네이버 블로그 키워드 검색 -> 워드 클라우드
# 참고 사이트 : https://developers.naver.com/docs/search/blog/

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request

client_id = "frBMA0JHYp1zATqntdUJ"
client_secret = "CzMu_Uce6r"

encText = urllib.parse.quote("신종코로나")

url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
#url = "https://openapi.naver.com/v1/search/news?query=" + encText # json 결과

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Sun, 28 Jun 2020 15:32:36 +0900",
# "total": 540135,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "2020#02 중국 남경 일상(feat. <b>신종 코로나</b> 바이러스)",
# "link": "https:\/\/blog.naver.com\/khe22ll?Redirect=Log&logNo=221786665272",
# "description": "초기대응에 실패해서 상황이 더 심각해지고 있는 <b>신종 코로나</b> 바이러스 감염증,, 일명, 우한 폐렴.... #허마 배달 필수템이 되어버림,,, <b>신종 코로나</b> 바이러스 덕분에 강제로 냉장고 털이 열심히함ㅠㅜ흑흑... 살... ",
# "bloggername": "여니스토리",
# "bloggerlink": "https://blog.naver.com/khe22ll",
# "postdate": "20200127"
#
# },
# {
# "title": "<b>신종코로나</b>바이러스 국내 확진자 833명, 코로나19가 미치는... ",
# "link": "https:\/\/blog.naver.com\/welcomebank1?Redirect=Log&logNo=221816488874",
# "description": "사스, 신종인플루엔자 그리고 코로나19 세계보건기구(WHO)는 중국 내 주요 전염병에 대한 자료를 발표했습니다. 현재 중국의 <b>신종코로나</b>바이러스 확진자는 77,150명, 사망자 수는 2,592명으로 통계 기준일 1월... ",
# "bloggername": "웰컴저축은행 공식 블로그",
# "bloggerlink": "https://blog.naver.com/welcomebank1",
# "postdate": "20200225"
#
# },
# {
# "title": "<b>신종코로나</b>보험 신중하게 확인하고 진행해보는 TIP",
# "link": "https:\/\/blog.naver.com\/singkfka?Redirect=Log&logNo=221888790043",
# "description": "<b>신종코로나</b>보험 신중하게 확인하고 진행해보는 TIP 안녕하세요. 오늘은 상해나 질병 관련해 여러 방면에서 폭넓게 보장받을 수 있는 종합보험에 대해 소개해드리고자 합니다. <b>신종코로나</b>보험 등의 보험이란... ",
# "bloggername": "리몬 블로그",
# "bloggerlink": "https://blog.naver.com/singkfka",
# "postdate": "20200403"
#
# },
# {
# "title": "| 우한폐렴 | <b>신종 코로나</b>바이러스 원인ㆍ증상ㆍ예방법",
# "link": "https:\/\/blog.naver.com\/lifetongwon?Redirect=Log&logNo=221798443484",
# "description": "<b>신종코로나</b>바이러스감염증 Novel Coronavirus Infectio <b>신종코로나</b>바이러스감염증, <b>신종코로나</b>바이러스, 코로나바이러스, 보건복지부 ncov.mohw.go.kr 우리 모두 미리미리 예방하여 아프지말고 건강하게 이겨냅시다!",
# "bloggername": "동원대학교",
# "bloggerlink": "https://blog.naver.com/lifetongwon",
# "postdate": "20200206"
#
# },
# {
# "title": "2020.2.3  <b>신종 코로나</b> 바이러스 폐렴과 중국 증시의 급락 개장.",
# "link": "https:\/\/blog.naver.com\/gaajur?Redirect=Log&logNo=221794559456",
# "description": "단기적으로는 악재 모멘텀과 함께 심리적인 불안감이 작용하고 있으나, <b>신종 코로나</b> 폐렴의 영향은... 중국의 <b>신종 코로나</b> 바이러스 폐렴은 3일 0시 현재 확진자 17,205명과 사망자 361명으로 계속 증가... ",
# "bloggername": "쥬라기의 세상을 보는 창",
# "bloggerlink": "https://blog.naver.com/gaajur",
# "postdate": "20200203"
#
# },
# {
# "title": "수도권 내 <b>신종 코로나</b>바이러스 감염증(코로나19) 집단감염... ",
# "link": "https:\/\/blog.naver.com\/johnkth?Redirect=Log&logNo=221996545029",
# "description": "보입니다 #<b>신종코로나</b>바이러스감염증 #코로나19집단감염 #성남은혜의강교회집단감염 #서울방문판매업체리치웨이 #서울탁구클럽 #행복한요양원 #부천쿠팡물류센터 #수원동부교회 #송파구강남대성학원... ",
# "bloggername": "현명한 투자자의 바른 길잡이",
# "bloggerlink": "https://blog.naver.com/johnkth",
# "postdate": "20200610"
#
# },
# {
# "title": "[투자레터11]<b>신종 코로나</b>바이러스 패닉 셀링 ★ 줍줍 종목은",
# "link": "https:\/\/blog.naver.com\/alloga?Redirect=Log&logNo=221788936604",
# "description": "설 연휴 끝나자마자 <b>신종 코로나</b>바이러스 감염증이 극성이네요. 중국 우한 때문에 정말이지 전 세계가... 이제는 코로나바이러스의 확산 여부를 주시하면서 평소에 하지 못했던 너무 올라 지켜만 봤던 섹터의... ",
# "bloggername": "친절한 성 기자의 재테크",
# "bloggerlink": "https://blog.naver.com/alloga",
# "postdate": "20200129"
#
# },
# {
# "title": "<b>신종 코로나</b>바이러스 예방 자동차 관리법",
# "link": "https:\/\/blog.naver.com\/exhappyway?Redirect=Log&logNo=221795217843",
# "description": "<b>신종 코로나</b>바이러스 확진자가 늘어남에 따라 바이러스 예방에 대한 관심이 높아지고 있습니다. 이럴 때일수록 항상 타고 다니는 자동차도 관리를 해줘야 하는데요 오늘은 <b>신종 코로나</b>바이러스 대비 자동차... ",
# "bloggername": "한국도로공사 공식블로그",
# "bloggerlink": "https://blog.naver.com/exhappyway",
# "postdate": "20200203"
#
# },
# {
# "title": "<b>신종코로나</b>바이러스 보험 정보 꼼꼼히 살펴보세요",
# "link": "https:\/\/blog.naver.com\/hui511?Redirect=Log&logNo=221895330631",
# "description": "코로나 때문에 밖에 못 나가서 가족과 지내는 시간이 늘어난 것도 어떻게 보면 좋은 것 아닐까 싶어요.... <b>신종코로나</b> 바이러스 때문에 전세계가 심각한 위기 상황을 맞은 것 같아요. 지금은 감염자수나... ",
# "bloggername": "hee ryungs",
# "bloggerlink": "https://blog.naver.com/hui511",
# "postdate": "20200407"
#
# },
# {
# "title": "<b>신종코로나</b>19 예방수칙과 대응법에는 어떤 것이 있을까?",
# "link": "https:\/\/blog.naver.com\/kangss0?Redirect=Log&logNo=221815427502",
# "description": "세계보건기구(WHO)에서 코로나 공식 명칭을 코로나19(COVID-19)로 지정했습니다. 최초에 중국 우한에서 발생하여 <b>신종 코로나</b> 바이러스라는 이름으로 불렸었는데요. 다시금 잠잠해지나 싶었지만 하루가 다르게... ",
# "bloggername": "맛있고 건강한 물 '한우물 미네랄정수기'",
# "bloggerlink": "https://blog.naver.com/kangss0",
# "postdate": "20200219"
#
# }
# ]
# }

# %% [markdown]
# ### requests 라이브러리 이용하기

# %%
import requests
from urllib.parse import urlparse

keyword="신종코로나"
url = "https://openapi.naver.com/v1/search/blog?query=" + keyword
result = requests.get(urlparse(url).geturl(),
                     headers = {"X-Naver-Client-Id":"frBMA0JHYp1zATqntdUJ",
                               "X-Naver-Client-Secret":"CzMu_Uce6r"})

print(result.json())
# Out:
# {'lastBuildDate': 'Sun, 28 Jun 2020 15:32:45 +0900', 'total': 540135, 'start': 1, 'display': 10, 'items': [{'title': '2020#02 중국 남경 일상(feat. <b>신종 코로나</b> 바이러스)', 'link': 'https://blog.naver.com/khe22ll?Redirect=Log&logNo=221786665272', 'description': '초기대응에 실패해서 상황이 더 심각해지고 있는 <b>신종 코로나</b> 바이러스 감염증,, 일명, 우한 폐렴.... #허마 배달 필수템이 되어버림,,, <b>신종 코로나</b> 바이러스 덕분에 강제로 냉장고 털이 열심히함ㅠㅜ흑흑... 살... ', 'bloggername': '여니스토리', 'bloggerlink': 'https://blog.naver.com/khe22ll', 'postdate': '20200127'}, {'title': '<b>신종코로나</b>바이러스 국내 확진자 833명, 코로나19가 미치는... ', 'link': 'https://blog.naver.com/welcomebank1?Redirect=Log&logNo=221816488874', 'description': '사스, 신종인플루엔자 그리고 코로나19 세계보건기구(WHO)는 중국 내 주요 전염병에 대한 자료를 발표했습니다. 현재 중국의 <b>신종코로나</b>바이러스 확진자는 77,150명, 사망자 수는 2,592명으로 통계 기준일 1월... ', 'bloggername': '웰컴저축은행 공식 블로그', 'bloggerlink': 'https://blog.naver.com/welcomebank1', 'postdate': '20200225'}, {'title': '<b>신종코로나</b>보험 신중하게 확인하고 진행해보는 TIP', 'link': 'https://blog.naver.com/singkfka?Redirect=Log&logNo=221888790043', 'description': '<b>신종코로나</b>보험 신중하게 확인하고 진행해보는 TIP 안녕하세요. 오늘은 상해나 질병 관련해 여러 방면에서 폭넓게 보장받을 수 있는 종합보험에 대해 소개해드리고자 합니다. <b>신종코로나</b>보험 등의 보험이란... ', 'bloggername': '리몬 블로그', 'bloggerlink': 'https://blog.naver.com/singkfka', 'postdate': '20200403'}, {'title': '| 우한폐렴 | <b>신종 코로나</b>바이러스 원인ㆍ증상ㆍ예방법', 'link': 'https://blog.naver.com/lifetongwon?Redirect=Log&logNo=221798443484', 'description': '<b>신종코로나</b>바이러스감염증 Novel Coronavirus Infectio <b>신종코로나</b>바이러스감염증, <b>신종코로나</b>바이러스, 코로나바이러스, 보건복지부 ncov.mohw.go.kr 우리 모두 미리미리 예방하여 아프지말고 건강하게 이겨냅시다!', 'bloggername': '동원대학교', 'bloggerlink': 'https://blog.naver.com/lifetongwon', 'postdate': '20200206'}, {'title': '2020.2.3  <b>신종 코로나</b> 바이러스 폐렴과 중국 증시의 급락 개장.', 'link': 'https://blog.naver.com/gaajur?Redirect=Log&logNo=221794559456', 'description': '단기적으로는 악재 모멘텀과 함께 심리적인 불안감이 작용하고 있으나, <b>신종 코로나</b> 폐렴의 영향은... 중국의 <b>신종 코로나</b> 바이러스 폐렴은 3일 0시 현재 확진자 17,205명과 사망자 361명으로 계속 증가... ', 'bloggername': '쥬라기의 세상을 보는 창', 'bloggerlink': 'https://blog.naver.com/gaajur', 'postdate': '20200203'}, {'title': '수도권 내 <b>신종 코로나</b>바이러스 감염증(코로나19) 집단감염... ', 'link': 'https://blog.naver.com/johnkth?Redirect=Log&logNo=221996545029', 'description': '보입니다 #<b>신종코로나</b>바이러스감염증 #코로나19집단감염 #성남은혜의강교회집단감염 #서울방문판매업체리치웨이 #서울탁구클럽 #행복한요양원 #부천쿠팡물류센터 #수원동부교회 #송파구강남대성학원... ', 'bloggername': '현명한 투자자의 바른 길잡이', 'bloggerlink': 'https://blog.naver.com/johnkth', 'postdate': '20200610'}, {'title': '[투자레터11]<b>신종 코로나</b>바이러스 패닉 셀링 ★ 줍줍 종목은', 'link': 'https://blog.naver.com/alloga?Redirect=Log&logNo=221788936604', 'description': '설 연휴 끝나자마자 <b>신종 코로나</b>바이러스 감염증이 극성이네요. 중국 우한 때문에 정말이지 전 세계가... 이제는 코로나바이러스의 확산 여부를 주시하면서 평소에 하지 못했던 너무 올라 지켜만 봤던 섹터의... ', 'bloggername': '친절한 성 기자의 재테크', 'bloggerlink': 'https://blog.naver.com/alloga', 'postdate': '20200129'}, {'title': '<b>신종 코로나</b>바이러스 예방 자동차 관리법', 'link': 'https://blog.naver.com/exhappyway?Redirect=Log&logNo=221795217843', 'description': '<b>신종 코로나</b>바이러스 확진자가 늘어남에 따라 바이러스 예방에 대한 관심이 높아지고 있습니다. 이럴 때일수록 항상 타고 다니는 자동차도 관리를 해줘야 하는데요 오늘은 <b>신종 코로나</b>바이러스 대비 자동차... ', 'bloggername': '한국도로공사 공식블로그', 'bloggerlink': 'https://blog.naver.com/exhappyway', 'postdate': '20200203'}, {'title': '<b>신종코로나</b>바이러스 보험 정보 꼼꼼히 살펴보세요', 'link': 'https://blog.naver.com/hui511?Redirect=Log&logNo=221895330631', 'description': '코로나 때문에 밖에 못 나가서 가족과 지내는 시간이 늘어난 것도 어떻게 보면 좋은 것 아닐까 싶어요.... <b>신종코로나</b> 바이러스 때문에 전세계가 심각한 위기 상황을 맞은 것 같아요. 지금은 감염자수나... ', 'bloggername': 'hee ryungs', 'bloggerlink': 'https://blog.naver.com/hui511', 'postdate': '20200407'}, {'title': '<b>신종코로나</b>19 예방수칙과 대응법에는 어떤 것이 있을까?', 'link': 'https://blog.naver.com/kangss0?Redirect=Log&logNo=221815427502', 'description': '세계보건기구(WHO)에서 코로나 공식 명칭을 코로나19(COVID-19)로 지정했습니다. 최초에 중국 우한에서 발생하여 <b>신종 코로나</b> 바이러스라는 이름으로 불렸었는데요. 다시금 잠잠해지나 싶었지만 하루가 다르게... ', 'bloggername': "맛있고 건강한 물 '한우물 미네랄정수기'", 'bloggerlink': 'https://blog.naver.com/kangss0', 'postdate': '20200219'}]}

# %% [markdown]
# ### 온라인 json 뷰어 이용하기 : http://jsonviewer.stack.hu/

# %%
import requests
from urllib.parse import urlparse

keyword="신종코로나"
url = "https://openapi.naver.com/v1/search/blog?query=" + keyword
result = requests.get(urlparse(url).geturl(),
                     headers = {"X-Naver-Client-Id":"frBMA0JHYp1zATqntdUJ",
                               "X-Naver-Client-Secret":"CzMu_Uce6r"})

json_obj = result.json()
print(json_obj['lastBuildDate'])
print(json_obj['total'])
print(json_obj['start'])
print(json_obj['display'])
# Out:
# Sun, 28 Jun 2020 15:32:51 +0900
# 540135
# 1
# 10

# %%
import requests
from urllib.parse import urlparse

keyword="신종코로나"
url = "https://openapi.naver.com/v1/search/blog?query=" + keyword
result = requests.get(urlparse(url).geturl(),
                     headers = {"X-Naver-Client-Id":"frBMA0JHYp1zATqntdUJ",
                               "X-Naver-Client-Secret":"CzMu_Uce6r"})

json_obj = result.json()
print(json_obj['items'])
# Out:
# [{'title': '2020#02 중국 남경 일상(feat. <b>신종 코로나</b> 바이러스)', 'link': 'https://blog.naver.com/khe22ll?Redirect=Log&logNo=221786665272', 'description': '초기대응에 실패해서 상황이 더 심각해지고 있는 <b>신종 코로나</b> 바이러스 감염증,, 일명, 우한 폐렴.... #허마 배달 필수템이 되어버림,,, <b>신종 코로나</b> 바이러스 덕분에 강제로 냉장고 털이 열심히함ㅠㅜ흑흑... 살... ', 'bloggername': '여니스토리', 'bloggerlink': 'https://blog.naver.com/khe22ll', 'postdate': '20200127'}, {'title': '<b>신종코로나</b>바이러스 국내 확진자 833명, 코로나19가 미치는... ', 'link': 'https://blog.naver.com/welcomebank1?Redirect=Log&logNo=221816488874', 'description': '사스, 신종인플루엔자 그리고 코로나19 세계보건기구(WHO)는 중국 내 주요 전염병에 대한 자료를 발표했습니다. 현재 중국의 <b>신종코로나</b>바이러스 확진자는 77,150명, 사망자 수는 2,592명으로 통계 기준일 1월... ', 'bloggername': '웰컴저축은행 공식 블로그', 'bloggerlink': 'https://blog.naver.com/welcomebank1', 'postdate': '20200225'}, {'title': '<b>신종코로나</b>보험 신중하게 확인하고 진행해보는 TIP', 'link': 'https://blog.naver.com/singkfka?Redirect=Log&logNo=221888790043', 'description': '<b>신종코로나</b>보험 신중하게 확인하고 진행해보는 TIP 안녕하세요. 오늘은 상해나 질병 관련해 여러 방면에서 폭넓게 보장받을 수 있는 종합보험에 대해 소개해드리고자 합니다. <b>신종코로나</b>보험 등의 보험이란... ', 'bloggername': '리몬 블로그', 'bloggerlink': 'https://blog.naver.com/singkfka', 'postdate': '20200403'}, {'title': '| 우한폐렴 | <b>신종 코로나</b>바이러스 원인ㆍ증상ㆍ예방법', 'link': 'https://blog.naver.com/lifetongwon?Redirect=Log&logNo=221798443484', 'description': '<b>신종코로나</b>바이러스감염증 Novel Coronavirus Infectio <b>신종코로나</b>바이러스감염증, <b>신종코로나</b>바이러스, 코로나바이러스, 보건복지부 ncov.mohw.go.kr 우리 모두 미리미리 예방하여 아프지말고 건강하게 이겨냅시다!', 'bloggername': '동원대학교', 'bloggerlink': 'https://blog.naver.com/lifetongwon', 'postdate': '20200206'}, {'title': '2020.2.3  <b>신종 코로나</b> 바이러스 폐렴과 중국 증시의 급락 개장.', 'link': 'https://blog.naver.com/gaajur?Redirect=Log&logNo=221794559456', 'description': '단기적으로는 악재 모멘텀과 함께 심리적인 불안감이 작용하고 있으나, <b>신종 코로나</b> 폐렴의 영향은... 중국의 <b>신종 코로나</b> 바이러스 폐렴은 3일 0시 현재 확진자 17,205명과 사망자 361명으로 계속 증가... ', 'bloggername': '쥬라기의 세상을 보는 창', 'bloggerlink': 'https://blog.naver.com/gaajur', 'postdate': '20200203'}, {'title': '수도권 내 <b>신종 코로나</b>바이러스 감염증(코로나19) 집단감염... ', 'link': 'https://blog.naver.com/johnkth?Redirect=Log&logNo=221996545029', 'description': '보입니다 #<b>신종코로나</b>바이러스감염증 #코로나19집단감염 #성남은혜의강교회집단감염 #서울방문판매업체리치웨이 #서울탁구클럽 #행복한요양원 #부천쿠팡물류센터 #수원동부교회 #송파구강남대성학원... ', 'bloggername': '현명한 투자자의 바른 길잡이', 'bloggerlink': 'https://blog.naver.com/johnkth', 'postdate': '20200610'}, {'title': '[투자레터11]<b>신종 코로나</b>바이러스 패닉 셀링 ★ 줍줍 종목은', 'link': 'https://blog.naver.com/alloga?Redirect=Log&logNo=221788936604', 'description': '설 연휴 끝나자마자 <b>신종 코로나</b>바이러스 감염증이 극성이네요. 중국 우한 때문에 정말이지 전 세계가... 이제는 코로나바이러스의 확산 여부를 주시하면서 평소에 하지 못했던 너무 올라 지켜만 봤던 섹터의... ', 'bloggername': '친절한 성 기자의 재테크', 'bloggerlink': 'https://blog.naver.com/alloga', 'postdate': '20200129'}, {'title': '<b>신종 코로나</b>바이러스 예방 자동차 관리법', 'link': 'https://blog.naver.com/exhappyway?Redirect=Log&logNo=221795217843', 'description': '<b>신종 코로나</b>바이러스 확진자가 늘어남에 따라 바이러스 예방에 대한 관심이 높아지고 있습니다. 이럴 때일수록 항상 타고 다니는 자동차도 관리를 해줘야 하는데요 오늘은 <b>신종 코로나</b>바이러스 대비 자동차... ', 'bloggername': '한국도로공사 공식블로그', 'bloggerlink': 'https://blog.naver.com/exhappyway', 'postdate': '20200203'}, {'title': '<b>신종코로나</b>바이러스 보험 정보 꼼꼼히 살펴보세요', 'link': 'https://blog.naver.com/hui511?Redirect=Log&logNo=221895330631', 'description': '코로나 때문에 밖에 못 나가서 가족과 지내는 시간이 늘어난 것도 어떻게 보면 좋은 것 아닐까 싶어요.... <b>신종코로나</b> 바이러스 때문에 전세계가 심각한 위기 상황을 맞은 것 같아요. 지금은 감염자수나... ', 'bloggername': 'hee ryungs', 'bloggerlink': 'https://blog.naver.com/hui511', 'postdate': '20200407'}, {'title': '<b>신종코로나</b>19 예방수칙과 대응법에는 어떤 것이 있을까?', 'link': 'https://blog.naver.com/kangss0?Redirect=Log&logNo=221815427502', 'description': '세계보건기구(WHO)에서 코로나 공식 명칭을 코로나19(COVID-19)로 지정했습니다. 최초에 중국 우한에서 발생하여 <b>신종 코로나</b> 바이러스라는 이름으로 불렸었는데요. 다시금 잠잠해지나 싶었지만 하루가 다르게... ', 'bloggername': "맛있고 건강한 물 '한우물 미네랄정수기'", 'bloggerlink': 'https://blog.naver.com/kangss0', 'postdate': '20200219'}]

# %% [markdown]
# ### 반복문으로 결과 출력하기

# %%
import requests
from urllib.parse import urlparse

keyword="신종코로나"
url = "https://openapi.naver.com/v1/search/blog?query=" + keyword
result = requests.get(urlparse(url).geturl(),
                     headers = {"X-Naver-Client-Id":"frBMA0JHYp1zATqntdUJ",
                               "X-Naver-Client-Secret":"CzMu_Uce6r"})

json_obj = result.json()

for item in json_obj['items']:
  print(item)
# Out:
# {'title': '2020#02 중국 남경 일상(feat. <b>신종 코로나</b> 바이러스)', 'link': 'https://blog.naver.com/khe22ll?Redirect=Log&logNo=221786665272', 'description': '초기대응에 실패해서 상황이 더 심각해지고 있는 <b>신종 코로나</b> 바이러스 감염증,, 일명, 우한 폐렴.... #허마 배달 필수템이 되어버림,,, <b>신종 코로나</b> 바이러스 덕분에 강제로 냉장고 털이 열심히함ㅠㅜ흑흑... 살... ', 'bloggername': '여니스토리', 'bloggerlink': 'https://blog.naver.com/khe22ll', 'postdate': '20200127'}
# {'title': '<b>신종코로나</b>바이러스 국내 확진자 833명, 코로나19가 미치는... ', 'link': 'https://blog.naver.com/welcomebank1?Redirect=Log&logNo=221816488874', 'description': '사스, 신종인플루엔자 그리고 코로나19 세계보건기구(WHO)는 중국 내 주요 전염병에 대한 자료를 발표했습니다. 현재 중국의 <b>신종코로나</b>바이러스 확진자는 77,150명, 사망자 수는 2,592명으로 통계 기준일 1월... ', 'bloggername': '웰컴저축은행 공식 블로그', 'bloggerlink': 'https://blog.naver.com/welcomebank1', 'postdate': '20200225'}
# {'title': '<b>신종코로나</b>보험 신중하게 확인하고 진행해보는 TIP', 'link': 'https://blog.naver.com/singkfka?Redirect=Log&logNo=221888790043', 'description': '<b>신종코로나</b>보험 신중하게 확인하고 진행해보는 TIP 안녕하세요. 오늘은 상해나 질병 관련해 여러 방면에서 폭넓게 보장받을 수 있는 종합보험에 대해 소개해드리고자 합니다. <b>신종코로나</b>보험 등의 보험이란... ', 'bloggername': '리몬 블로그', 'bloggerlink': 'https://blog.naver.com/singkfka', 'postdate': '20200403'}
# {'title': '| 우한폐렴 | <b>신종 코로나</b>바이러스 원인ㆍ증상ㆍ예방법', 'link': 'https://blog.naver.com/lifetongwon?Redirect=Log&logNo=221798443484', 'description': '<b>신종코로나</b>바이러스감염증 Novel Coronavirus Infectio <b>신종코로나</b>바이러스감염증, <b>신종코로나</b>바이러스, 코로나바이러스, 보건복지부 ncov.mohw.go.kr 우리 모두 미리미리 예방하여 아프지말고 건강하게 이겨냅시다!', 'bloggername': '동원대학교', 'bloggerlink': 'https://blog.naver.com/lifetongwon', 'postdate': '20200206'}
# {'title': '2020.2.3  <b>신종 코로나</b> 바이러스 폐렴과 중국 증시의 급락 개장.', 'link': 'https://blog.naver.com/gaajur?Redirect=Log&logNo=221794559456', 'description': '단기적으로는 악재 모멘텀과 함께 심리적인 불안감이 작용하고 있으나, <b>신종 코로나</b> 폐렴의 영향은... 중국의 <b>신종 코로나</b> 바이러스 폐렴은 3일 0시 현재 확진자 17,205명과 사망자 361명으로 계속 증가... ', 'bloggername': '쥬라기의 세상을 보는 창', 'bloggerlink': 'https://blog.naver.com/gaajur', 'postdate': '20200203'}
# {'title': '수도권 내 <b>신종 코로나</b>바이러스 감염증(코로나19) 집단감염... ', 'link': 'https://blog.naver.com/johnkth?Redirect=Log&logNo=221996545029', 'description': '보입니다 #<b>신종코로나</b>바이러스감염증 #코로나19집단감염 #성남은혜의강교회집단감염 #서울방문판매업체리치웨이 #서울탁구클럽 #행복한요양원 #부천쿠팡물류센터 #수원동부교회 #송파구강남대성학원... ', 'bloggername': '현명한 투자자의 바른 길잡이', 'bloggerlink': 'https://blog.naver.com/johnkth', 'postdate': '20200610'}
# {'title': '[투자레터11]<b>신종 코로나</b>바이러스 패닉 셀링 ★ 줍줍 종목은', 'link': 'https://blog.naver.com/alloga?Redirect=Log&logNo=221788936604', 'description': '설 연휴 끝나자마자 <b>신종 코로나</b>바이러스 감염증이 극성이네요. 중국 우한 때문에 정말이지 전 세계가... 이제는 코로나바이러스의 확산 여부를 주시하면서 평소에 하지 못했던 너무 올라 지켜만 봤던 섹터의... ', 'bloggername': '친절한 성 기자의 재테크', 'bloggerlink': 'https://blog.naver.com/alloga', 'postdate': '20200129'}
# {'title': '<b>신종 코로나</b>바이러스 예방 자동차 관리법', 'link': 'https://blog.naver.com/exhappyway?Redirect=Log&logNo=221795217843', 'description': '<b>신종 코로나</b>바이러스 확진자가 늘어남에 따라 바이러스 예방에 대한 관심이 높아지고 있습니다. 이럴 때일수록 항상 타고 다니는 자동차도 관리를 해줘야 하는데요 오늘은 <b>신종 코로나</b>바이러스 대비 자동차... ', 'bloggername': '한국도로공사 공식블로그', 'bloggerlink': 'https://blog.naver.com/exhappyway', 'postdate': '20200203'}
# {'title': '<b>신종코로나</b>바이러스 보험 정보 꼼꼼히 살펴보세요', 'link': 'https://blog.naver.com/hui511?Redirect=Log&logNo=221895330631', 'description': '코로나 때문에 밖에 못 나가서 가족과 지내는 시간이 늘어난 것도 어떻게 보면 좋은 것 아닐까 싶어요.... <b>신종코로나</b> 바이러스 때문에 전세계가 심각한 위기 상황을 맞은 것 같아요. 지금은 감염자수나... ', 'bloggername': 'hee ryungs', 'bloggerlink': 'https://blog.naver.com/hui511', 'postdate': '20200407'}
# {'title': '<b>신종코로나</b>19 예방수칙과 대응법에는 어떤 것이 있을까?', 'link': 'https://blog.naver.com/kangss0?Redirect=Log&logNo=221815427502', 'description': '세계보건기구(WHO)에서 코로나 공식 명칭을 코로나19(COVID-19)로 지정했습니다. 최초에 중국 우한에서 발생하여 <b>신종 코로나</b> 바이러스라는 이름으로 불렸었는데요. 다시금 잠잠해지나 싶었지만 하루가 다르게... ', 'bloggername': "맛있고 건강한 물 '한우물 미네랄정수기'", 'bloggerlink': 'https://blog.naver.com/kangss0', 'postdate': '20200219'}

# %% [markdown]
# ### 특정 속성값만 뽑아내기

# %%
import requests
from urllib.parse import urlparse

keyword="신종코로나"
url = "https://openapi.naver.com/v1/search/blog?query=" + keyword
result = requests.get(urlparse(url).geturl(),
                     headers = {"X-Naver-Client-Id":"frBMA0JHYp1zATqntdUJ",
                               "X-Naver-Client-Secret":"CzMu_Uce6r"})

json_obj = result.json()

for item in json_obj['items']:
  print(item['title'])
# Out:
# 2020#02 중국 남경 일상(feat. <b>신종 코로나</b> 바이러스)
# <b>신종코로나</b>바이러스 국내 확진자 833명, 코로나19가 미치는...
# <b>신종코로나</b>보험 신중하게 확인하고 진행해보는 TIP
# | 우한폐렴 | <b>신종 코로나</b>바이러스 원인ㆍ증상ㆍ예방법
# 2020.2.3  <b>신종 코로나</b> 바이러스 폐렴과 중국 증시의 급락 개장.
# 수도권 내 <b>신종 코로나</b>바이러스 감염증(코로나19) 집단감염...
# [투자레터11]<b>신종 코로나</b>바이러스 패닉 셀링 ★ 줍줍 종목은
# <b>신종 코로나</b>바이러스 예방 자동차 관리법
# <b>신종코로나</b>바이러스 보험 정보 꼼꼼히 살펴보세요
# <b>신종코로나</b>19 예방수칙과 대응법에는 어떤 것이 있을까?

# %% [markdown]
# ### b, /b 없애기

# %%
import requests
from urllib.parse import urlparse

keyword="신종코로나"
url = "https://openapi.naver.com/v1/search/blog?query=" + keyword
result = requests.get(urlparse(url).geturl(),
                     headers = {"X-Naver-Client-Id":"frBMA0JHYp1zATqntdUJ",
                               "X-Naver-Client-Secret":"CzMu_Uce6r"})

json_obj = result.json()

for item in json_obj['items']:
  print(item['title'].replace("<b>", "").replace("</b>", ""))
# Out:
# 2020#02 중국 남경 일상(feat. 신종 코로나 바이러스)
# 신종코로나바이러스 국내 확진자 833명, 코로나19가 미치는...
# 신종코로나보험 신중하게 확인하고 진행해보는 TIP
# | 우한폐렴 | 신종 코로나바이러스 원인ㆍ증상ㆍ예방법
# 2020.2.3  신종 코로나 바이러스 폐렴과 중국 증시의 급락 개장.
# 수도권 내 신종 코로나바이러스 감염증(코로나19) 집단감염...
# [투자레터11]신종 코로나바이러스 패닉 셀링 ★ 줍줍 종목은
# 신종 코로나바이러스 예방 자동차 관리법
# 신종코로나바이러스 보험 정보 꼼꼼히 살펴보세요
# 신종코로나19 예방수칙과 대응법에는 어떤 것이 있을까?

# %% [markdown]
# ### title, link 출력

# %%
import requests
from urllib.parse import urlparse

keyword="신종코로나"
url = "https://openapi.naver.com/v1/search/blog?query=" + keyword
result = requests.get(urlparse(url).geturl(),
                     headers = {"X-Naver-Client-Id":"frBMA0JHYp1zATqntdUJ",
                               "X-Naver-Client-Secret":"CzMu_Uce6r"})

json_obj = result.json()

for item in json_obj['items']:
  print(item['title'].replace("<b>", "").replace("</b>", ""),
        item['link'])
# Out:
# 2020#02 중국 남경 일상(feat. 신종 코로나 바이러스) https://blog.naver.com/khe22ll?Redirect=Log&logNo=221786665272
# 신종코로나바이러스 국내 확진자 833명, 코로나19가 미치는...  https://blog.naver.com/welcomebank1?Redirect=Log&logNo=221816488874
# 신종코로나보험 신중하게 확인하고 진행해보는 TIP https://blog.naver.com/singkfka?Redirect=Log&logNo=221888790043
# | 우한폐렴 | 신종 코로나바이러스 원인ㆍ증상ㆍ예방법 https://blog.naver.com/lifetongwon?Redirect=Log&logNo=221798443484
# 2020.2.3  신종 코로나 바이러스 폐렴과 중국 증시의 급락 개장. https://blog.naver.com/gaajur?Redirect=Log&logNo=221794559456
# 수도권 내 신종 코로나바이러스 감염증(코로나19) 집단감염...  https://blog.naver.com/johnkth?Redirect=Log&logNo=221996545029
# [투자레터11]신종 코로나바이러스 패닉 셀링 ★ 줍줍 종목은 https://blog.naver.com/alloga?Redirect=Log&logNo=221788936604
# 신종 코로나바이러스 예방 자동차 관리법 https://blog.naver.com/exhappyway?Redirect=Log&logNo=221795217843
# 신종코로나바이러스 보험 정보 꼼꼼히 살펴보세요 https://blog.naver.com/hui511?Redirect=Log&logNo=221895330631
# 신종코로나19 예방수칙과 대응법에는 어떤 것이 있을까? https://blog.naver.com/kangss0?Redirect=Log&logNo=221815427502

# %% [markdown]
# ### 여러 페이지 호출하기 : 100개 결과 뽑기

# %%
import requests
from urllib.parse import urlparse

# 함수 선언 
def get_api_result(keyword, display, start) :
    url = "https://openapi.naver.com/v1/search/blog?query=" + keyword + "&display=" + str(display) + "&start=" + str(start)
    result = requests.get(urlparse(url).geturl(),
                        headers = {"X-Naver-Client-Id":"frBMA0JHYp1zATqntdUJ",
                                  "X-Naver-Client-Secret":"CzMu_Uce6r"})
    return result.json()


def call_and_print(keyword, page):
    json_obj = get_api_result(keyword, 100, page)
    for item in json_obj['items'] :
        print(item)

# 메인 코드   
keyword="신종코로나"
call_and_print(keyword, 1) # 1-100
#call_and_print(keyword, 101) # 101-200
# Out:
# {'title': '2020#02 중국 남경 일상(feat. <b>신종 코로나</b> 바이러스)', 'link': 'https://blog.naver.com/khe22ll?Redirect=Log&logNo=221786665272', 'description': '초기대응에 실패해서 상황이 더 심각해지고 있는 <b>신종 코로나</b> 바이러스 감염증,, 일명, 우한 폐렴.... #허마 배달 필수템이 되어버림,,, <b>신종 코로나</b> 바이러스 덕분에 강제로 냉장고 털이 열심히함ㅠㅜ흑흑... 살... ', 'bloggername': '여니스토리', 'bloggerlink': 'https://blog.naver.com/khe22ll', 'postdate': '20200127'}
# {'title': '<b>신종코로나</b>바이러스 국내 확진자 833명, 코로나19가 미치는... ', 'link': 'https://blog.naver.com/welcomebank1?Redirect=Log&logNo=221816488874', 'description': '사스, 신종인플루엔자 그리고 코로나19 세계보건기구(WHO)는 중국 내 주요 전염병에 대한 자료를 발표했습니다. 현재 중국의 <b>신종코로나</b>바이러스 확진자는 77,150명, 사망자 수는 2,592명으로 통계 기준일 1월... ', 'bloggername': '웰컴저축은행 공식 블로그', 'bloggerlink': 'https://blog.naver.com/welcomebank1', 'postdate': '20200225'}
# {'title': '<b>신종코로나</b>보험 신중하게 확인하고 진행해보는 TIP', 'link': 'https://blog.naver.com/singkfka?Redirect=Log&logNo=221888790043', 'description': '<b>신종코로나</b>보험 신중하게 확인하고 진행해보는 TIP 안녕하세요. 오늘은 상해나 질병 관련해 여러 방면에서 폭넓게 보장받을 수 있는 종합보험에 대해 소개해드리고자 합니다. <b>신종코로나</b>보험 등의 보험이란... ', 'bloggername': '리몬 블로그', 'bloggerlink': 'https://blog.naver.com/singkfka', 'postdate': '20200403'}
# {'title': '<b>신종코로나</b>19 예방수칙과 대응법에는 어떤 것이 있을까?', 'link': 'https://blog.naver.com/kangss0?Redirect=Log&logNo=221815427502', 'description': '세계보건기구(WHO)에서 코로나 공식 명칭을 코로나19(COVID-19)로 지정했습니다. 최초에 중국 우한에서 발생하여 <b>신종 코로나</b> 바이러스라는 이름으로 불렸었는데요. 다시금 잠잠해지나 싶었지만 하루가 다르게... ', 'bloggername': "맛있고 건강한 물 '한우물 미네랄정수기'", 'bloggerlink': 'https://blog.naver.com/kangss0', 'postdate': '20200219'}
# {'title': '<b>신종 코로나</b> 바이러스 19를 대처하는 중국정부, 본질을 흐리고... ', 'link': 'https://blog.naver.com/ynk5789?Redirect=Log&logNo=221826355626', 'description': '<b>신종 코로나</b>가 어디에서 발생을 했는가 ? 중국은 자신들이 퍼트린 코로나 바이러스 사태에 대해 전혀 부끄러워하지도 책임감도 없어 보인다. 전 세계가 코로나 바이러스때문에 몸살을 앓고 있다. 그렇지만... ', 'bloggername': '골 때리는 중국, 못말리는 중국인', 'bloggerlink': 'https://blog.naver.com/ynk5789', 'postdate': '20200226'}
# {'title': '<b>신종코로나</b>보험 주의사항 잊지 말고 확인해보세요', 'link': 'https://blog.naver.com/ddl07069?Redirect=Log&logNo=221928330471', 'description': '특히나 코로나 19 바이러스 때문에 <b>신종코로나</b>보험에 대한 문의도 많아지고 있습니다. 보험회사마다 보장해주는 내용이 다르다 보니 문의를 주시는 것 같네요. 코로나 보험을 알아보고 계시다면 통합보험을... ', 'bloggername': 'HY :)', 'bloggerlink': 'https://blog.naver.com/ddl07069', 'postdate': '20200425'}
# {'title': '<b>신종코로나</b> 방역 이제는 걱정 없어요', 'link': 'https://blog.naver.com/sniki36?Redirect=Log&logNo=221840985895', 'description': '아무래도 전문가를 불러 <b>신종코로나</b> 방역을 하면 찾아주시는 분들이나 상주하는 직원들이 조금 더... 그런 모습을 보고 나니 왜 많은 업주 분들이 <b>신종코로나</b> 방역을 위해 다잘에 연락을 했었는지 알게 되었어요.... ', 'bloggername': '사랑다정하리♡', 'bloggerlink': 'https://blog.naver.com/sniki36', 'postdate': '20200306'}
# {'title': '아비간 일본에서 <b>코로나</b>19 치료제로 <b>신종</b>플루약 처방', 'link': 'https://blog.naver.com/sol_2love?Redirect=Log&logNo=221820240926', 'description': '크루즈 관련하여 우리나라보다 먼저 <b>신종 코로나</b> 바이러스의 문제를 크게 겪고 있는 일본에서 신종플루 약으로 유명한 바이러스 치료제 #아비간 을 코로나치료제로 사용하라는 정부와 아베 신조 일본... ', 'bloggername': '행복한은진씨의 뷰티풀라이프', 'bloggerlink': 'https://blog.naver.com/sol_2love', 'postdate': '20200222'}
# {'title': '<b>신종 코로나</b> 바이러스와 싸우는 로봇', 'link': 'https://blog.naver.com/futurejob8888?Redirect=Log&logNo=221802231257', 'description': '사스, 메르스, 에볼라, <b>신종 코로나</b> 바이러스와 같이 새로운 종류의 바이러스가 사람들의 목숨을... | 원격진료 로봇 지난 1월 미국에서 첫 번째 <b>신종 코로나</b> 바이러스 확진자가 발생했을 때 감염자가... ', 'bloggername': 'futurejob 퓨처잡', 'bloggerlink': 'https://blog.naver.com/futurejob8888', 'postdate': '20200209'}
# {'title': '<b>신종 코로나</b>바이러스 자가격리 대상자 생활수칙!', 'link': 'https://blog.naver.com/seouledu2012?Redirect=Log&logNo=221805020171', 'description': '<b>신종 코로나</b>바이러스 예방수칙! 잘 지키며 생활하고 계시나요? □ 사람이 많은 곳 방문 시 마스크 착용... (감시 중 117명, 감시 해제 724명) 오늘은 여러 번 강조해도 부족하지 않은 <b>신종 코로나</b>바이러스 예방법... ', 'bloggername': '서울교육나침반', 'bloggerlink': 'https://blog.naver.com/seouledu2012', 'postdate': '20200211'}
# {'title': '<b>신종 코로나</b>바이러스 - 메르스와 우한폐렴 비교', 'link': 'https://blog.naver.com/ipudo?Redirect=Log&logNo=221788745013', 'description': '2015년 대한민국을 공포에 몰아넣었던 메르스와 2020년 우한폐렴(<b>신종 코로나</b>바이러스 감염)은 무엇이 다르고 무엇이 다를까. 1. 공통점 - 같은 코로나바이러스 패밀리라는 점 - 둘 다 독성이 강한 쪽으로... ', 'bloggername': '노환규 블로그', 'bloggerlink': 'https://blog.naver.com/ipudo', 'postdate': '20200129'}
# {'title': '중국 우한 <b>신종 코로나</b> 바이러스 병원이 10일 만에 완공... ', 'link': 'https://blog.naver.com/leeandarchi?Redirect=Log&logNo=221798221911', 'description': '요즘 중국 우한시에서 생겨난 <b>신종 코로나</b> 바이러스에 전세계가 비상입니다. 사스나 메르스와는 달리... 하지만 이런 <b>신종 코로나</b> 바이러스 만큼 화제가 된것이 있었는데요, 바로 중국 정부가 우한 시에... ', 'bloggername': '리엔_건축전문블로그', 'bloggerlink': 'https://blog.naver.com/leeandarchi', 'postdate': '20200206'}
# {'title': '<b>신종 코로나</b>바이러스 비켜, 손소독제 만들기!', 'link': 'https://blog.naver.com/o2gunpo?Redirect=Log&logNo=221799864256', 'description': '7개 코로나바이러스 중 하나입니다. 감염자의 침방울이 호흡기나 눈. 코. 입의 점막으로 침투할 때 전염됩니다. <b>신종 코로나</b>바이러스에 감염되면 약 2~14일(추정)의 잠복기를 거친 후에 발열 및 기침이나... ', 'bloggername': '시민 우선 사람 중심 군포', 'bloggerlink': 'https://blog.naver.com/o2gunpo', 'postdate': '20200207'}
# {'title': '미국, <b>신종 코로나</b> 감염자 치료에 로봇 투입', 'link': 'https://blog.naver.com/tech-plus?Redirect=Log&logNo=221789725047', 'description': '미국 첫 <b>신종 코로나</b>바이러스 감염증 확진 판정을 받은 남성이 격리 치료를 받고 있는데, 의료진이... 점과 <b>신종 코로나</b> 감염 증상이 자신의 상태와 유사하다는 것을 들어 직접 의료기관을 찾았고, 현재... ', 'bloggername': '테크플러스', 'bloggerlink': 'https://blog.naver.com/tech-plus', 'postdate': '20200130'}
# {'title': '<b>신종코로나</b>바이러스 예방 안내문', 'link': 'https://blog.naver.com/fptvmf1202?Redirect=Log&logNo=221849666735', 'description': '<b>신종코로나</b>바이러스는 2019년 12월 중국 우한에서 처음 발생한 후, 전세계로 확실된 새로운 유형의 바이러스이며, 정확한 명칭은 코로나바이러스감염증-19(COVID-19) 입니다. 주요증상으로는 발열과 기침, 인후통... ', 'bloggername': '기윤맘', 'bloggerlink': 'https://blog.naver.com/fptvmf1202', 'postdate': '20200312'}
# {'title': '<b>신종코로나</b>19바이러스 생존기간', 'link': 'https://blog.naver.com/dews333?Redirect=Log&logNo=221788403617', 'description': '10일자 기사입니다 기사는 COVID-19에 관한 정보 인 듯 싶지만 자세히 보시면 기존코로나바이러스에 관한 내용이에요 현재 유행중인 <b>신종코로나</b>19바이러스는 계속 연구중이라고 하는데요 2-2.... ', 'bloggername': '。˚。¨ARIRING♡ ¨', 'bloggerlink': 'https://blog.naver.com/dews333', 'postdate': '20200129'}
# {'title': '[한샘홈케어 똑똑TIP] <b>신종 코로나</b>19 예방, 한샘 방역살균케어', 'link': 'https://blog.naver.com/hanssem70?Redirect=Log&logNo=221825954699', 'description': '한샘 방역살균케어에 대해 함께 알아봐요 :) <b>신종 코로나</b>19 예방, 한샘 방역살균케어 중국에서부터 시작된 신종 바이러스 코로나 19가 전 세계로 확산되면서 우리나라도 현재 확진자가 1000명이 넘은 심각 단계에... ', 'bloggername': '집꾸밈에 대한 모든 것, 한샘닷컴에서 만나보세요', 'bloggerlink': 'https://blog.naver.com/hanssem70', 'postdate': '20200226'}
# {'title': '<b>신종 코로나</b>바이러스 감염증 합동 브리핑(9차)', 'link': 'https://blog.naver.com/happyjejudo?Redirect=Log&logNo=221799755135', 'description': '<b>신종 코로나</b>바이러스의 피해 확산을 막기위한 정책이 다방면으로 진행되고 있어요. 도민여러분께서도 국민 예방수칙을 준수하고 코로나바이러스 확산 방지에 힘써주시기 바랍니다!', 'bloggername': '제주특별자치도', 'bloggerlink': 'https://blog.naver.com/happyjejudo', 'postdate': '20200207'}
# {'title': '<b>신종코로나</b>바이러스(nCoV)는 무엇인가?', 'link': 'https://blog.naver.com/genetic2002?Redirect=Log&logNo=221785606683', 'description': '최근 국내에도 코로나바이러스 감염 확진자가 나타나 보건당국 및 국민들이 긴장하고 있습니다.... <b>신종 코로나</b>바이러스에 처음 감염된 대부분 환자는 후베이성 우한시 화난수산시장... ', 'bloggername': '다니엘 생명과학 이야기', 'bloggerlink': 'https://blog.naver.com/genetic2002', 'postdate': '20200126'}
# {'title': '<b>신종코로나</b> - 최대집 회장에 대한 평가', 'link': 'https://blog.naver.com/ipudo?Redirect=Log&logNo=221836084407', 'description': '1) 1명을 막는 것이 중요하다 <b>신종 코로나</b>는 단 1명에서 시작됐다. 동물로부터 감염된 단 한 사람에서... 즉 <b>신종코로나</b>의 발원지인 중국에서 한국으로 바이러스가 넘어온다는 것은 사람을 통해서만 넘어올 수... ', 'bloggername': '노환규 블로그', 'bloggerlink': 'https://blog.naver.com/ipudo', 'postdate': '20200303'}
# {'title': '<b>신종 코로나</b>바이러스 예방을 위한 면역력에 좋은 음식 7가지', 'link': 'https://blog.naver.com/rains1230?Redirect=Log&logNo=221834227815', 'description': '분들은 코로나 바이러스에 취약하기 때문에 면역력을 높여야하는데요 <b>신종 코로나</b> 면역력을 기르기 위해서는 평소에 면역력에 좋은 음식을 챙겨먹는게 좋아요 그래서 오늘은 면역력에 도움이 되는... ', 'bloggername': 'His Story', 'bloggerlink': 'https://blog.naver.com/rains1230', 'postdate': '20200302'}
# {'title': '<b>신종 코로나</b> - 나쁜 전문가들과 더 나쁜 전문가', 'link': 'https://blog.naver.com/ipudo?Redirect=Log&logNo=221842801206', 'description': '같은 자리에서 김동현 한국역학회 회장은 이렇게 말했다.- &quot;후베이성 이외 중국의 <b>신종 코로나</b>바이러... 그리고 그 결과 대한민국은 중국 다음으로 코로나바이러스가 창궐하는 나라가 되었고, 2020.3.7 현재... ', 'bloggername': '노환규 블로그', 'bloggerlink': 'https://blog.naver.com/ipudo', 'postdate': '20200308'}
# {'title': '<b>신종 코로나</b> - 3/6의 전망', 'link': 'https://blog.naver.com/ipudo?Redirect=Log&logNo=221841157088', 'description': '대한민국의 상황 3/6 현재 대한민국의 <b>신종 코로나</b> 발생상황은 아래와 같다. (3/2 이전에는 오후4시 기준... 그렇다면 강제봉쇄정책의 효과와 날씨의 변화(상승하는 온도 - 코로나바이러스가 가장 활발한 때는... ', 'bloggername': '노환규 블로그', 'bloggerlink': 'https://blog.naver.com/ipudo', 'postdate': '20200306'}
# {'title': '에이프로젠 <b>신종 코로나</b>바이러스 감염증(코로나19)에 대한... ', 'link': 'https://blog.naver.com/johnkth?Redirect=Log&logNo=222011943002', 'description': '있기 때문에 지속성을 갖기에는 한계가 있어 보입니다 투자에 참고하세요 #에이프로젠 #에이프로젠KIC #에이프로젠H&amp;G #<b>신종코로나</b>바이러스감염증 #코로나19융합항체차단효과 #코로나19백신 #코로나19치료제', 'bloggername': '현명한 투자자의 바른 길잡이', 'bloggerlink': 'https://blog.naver.com/johnkth', 'postdate': '20200625'}
# {'title': '<b>신종 코로나</b>바이러스 감염증 합동 브리핑(11차)', 'link': 'https://blog.naver.com/happyjejudo?Redirect=Log&logNo=221803173669', 'description': "검역… <b>신종 코로나</b> 유입 원천 봉쇄 &lt; 국내 발생동향(’20.2.10. 09시 기준) &gt; 구분 확진환자(누계) 계 입원 중 퇴원 전국 27 24 3 제주도 0 0 0 <b>신종 코로나</b>바이러스 영향 최소화 및 경제위기 극복위한 '범도민... ", 'bloggername': '제주특별자치도', 'bloggerlink': 'https://blog.naver.com/happyjejudo', 'postdate': '20200210'}
# {'title': '<b>신종 코로나</b>바이러스 예방을 위한 면역력 높이기', 'link': 'https://blog.naver.com/safeppy?Redirect=Log&logNo=221798335034', 'description': '<b>신종 코로나</b>바이러스 예방을 위한 면역력 높이기 손 씻기, 마스크 착용과 함께 코로나바이러스 감염증 및 각종 질병으로부터 자신을 지키는 방법은 면역력을 높이는 것입니다. 면역력이란? 면역력이란 외부에서... ', 'bloggername': '대한민국 119_소방청 공식 블로그', 'bloggerlink': 'https://blog.naver.com/safeppy', 'postdate': '20200206'}
# {'title': '<b>신종코로나</b> 막는 마스크 사용법!', 'link': 'https://blog.naver.com/nature_food?Redirect=Log&logNo=221796215462', 'description': '4 마이크로미터 입자를 94% 이상 차단 -입자성 유해물질과 신종플루 등 감염원으로부터 호흡기 보호... 통해 코로나 바이러스를 예방할 수 있습니다. 한편, <b>신종코로나</b> 바이러스가 의심될 경우, 가까운... ', 'bloggername': '푸드케어', 'bloggerlink': 'https://blog.naver.com/nature_food', 'postdate': '20200204'}
# {'title': '<b>신종 코로나</b>바이러스 감염증과 감기 독감의 차이점 어떤게... ', 'link': 'https://blog.naver.com/daejeontour?Redirect=Log&logNo=221806139169', 'description': '상기하여 바이러스로 부터 멀어지는 건강한 생활하시기 바랍니다! 여러분 모두의 안전과 건강을 위해 먼저보슈도 응원하겠습니다! #<b>신종코로나</b> #코로나감기차이점 #코로나독감차이 #<b>신종코로나</b>예방법 #먼저보슈', 'bloggername': '대전공식관광블로그 대전~ 여행~', 'bloggerlink': 'https://blog.naver.com/daejeontour', 'postdate': '20200212'}
# {'title': '비말차단마스크,덴탈마스크 구입과 <b>신종 코로나</b>', 'link': 'https://blog.naver.com/bestpen?Redirect=Log&logNo=221990856230', 'description': '특히, <b>신종 코로나</b>의 감염위험이 높은 기저질환자나 노인,임산부 등의 노약자들은 참고해야 합니다. 그렇지 않아도 <b>신종 코로나</b> 확진자들이 지속적으로 발생하고 있어서 더욱 주의를 해야 하는 시기입니다.... ', 'bloggername': '소설가 김상헌', 'bloggerlink': 'https://blog.naver.com/bestpen', 'postdate': '20200605'}
# {'title': '열지 마세요! ‘<b>신종 코로나</b>’ 피싱 메일', 'link': 'https://blog.naver.com/ibm_korea?Redirect=Log&logNo=221807705017', 'description': 'https://ibm.biz/BdYQeg #한국IBM #IBM블로그 #IT기업 #<b>신종코로나</b> #코로나 #코로나바이러스 #<b>신종코로나</b>바이러스 #코로나19 #피싱메일 #악성코드 #인공지능 #클라우드 #블록체인 #사물인터넷 #IT인프라 #보안', 'bloggername': 'IBM KOREA', 'bloggerlink': 'https://blog.naver.com/ibm_korea', 'postdate': '20200214'}
# {'title': '<b>신종 코로나</b>와 대한의사협회', 'link': 'https://blog.naver.com/ipudo?Redirect=Log&logNo=221820424649', 'description': '언론에 제대로 보도되지 않았지만, 2020년 <b>신종 코로나</b> 사태를 맞아 대한의사협회는 눈물겨운 노력을 했다. 그 중에서도 중국이라는 감염원 차단에 대한 중요성을 감염초기부터 지속적으로... ', 'bloggername': '노환규 블로그', 'bloggerlink': 'https://blog.naver.com/ipudo', 'postdate': '20200223'}
# {'title': '<b>신종 코로나</b>바이러스 불안감에따른 우울증', 'link': 'https://blog.naver.com/yoynghwa6?Redirect=Log&logNo=221802914155', 'description': '좀더 행복한세상이 될테지요 정신까지 건강한 그런 세상을 희망합니다 #<b>신종코로나</b>바이러스우울증 #<b>신종코로나</b>바이러스공포 #우울증극복방법 #따뜻한세상 #<b>신종코로나</b>바이러스정신건강 #코로나바이러스불안감', 'bloggername': '최영화해피바이러스 : 최고잔치mc 010-3660-6004', 'bloggerlink': 'https://blog.naver.com/yoynghwa6', 'postdate': '20200210'}
# {'title': '<b>신종 코로나</b> - 유학생 모녀에 대한 정치쇼', 'link': 'https://blog.naver.com/ipudo?Redirect=Log&logNo=221881731716', 'description': '<b>신종코로나</b> 증상이 있는데도 제주도를 다녀옴으로써 제주도에 피해를 준 유학생 모녀에 대해... (언론에 보도된 역학조사 결과에 의하면, 학생이 <b>신종코로나</b>증상을 보인 것은 여행 마지막날인 24일부터였다고... ', 'bloggername': '노환규 블로그', 'bloggerlink': 'https://blog.naver.com/ipudo', 'postdate': '20200330'}
# {'title': '<b>신종 코로나</b>바이러스 감염증(코로나19) 신규 확진자 수도권... ', 'link': 'https://blog.naver.com/johnkth?Redirect=Log&logNo=221982757003', 'description': '수도권에 집중적으로 발생하고 이쓴 신규 코로나19 확진자들로 다시금 사회속 거리두기로 돌아갈 위험성이 높아지고 있습니다 투자에 참고하세요 #<b>신종코로나</b>바이러스감염증 #코로나19 #코로나19확진자... ', 'bloggername': '현명한 투자자의 바른 길잡이', 'bloggerlink': 'https://blog.naver.com/johnkth', 'postdate': '20200529'}
# {'title': '끝나지 않는 상하이의 <b>신종코로나</b>', 'link': 'https://blog.naver.com/annerheekim?Redirect=Log&logNo=221968198062', 'description': '상하이에서 <b>신종코로나</b> 확진자가 나왔습니다. https://mp.weixin.qq.com/s/MEF2VeFCm4WSvcvoAGusXQ... 어제 오랜만에 단지 정문으로 물건을 받으러 나갔는데 저희 단지만 해도 날씨가 더워져서 그런가 <b>신종코로나</b>가... ', 'bloggername': '길벗의 앤 Anne @ Wuxi & Shanghai', 'bloggerlink': 'https://blog.naver.com/annerheekim', 'postdate': '20200518'}
# {'title': '이탈리아에서는 왜 <b>신종 코로나</b> 사망률이 높은가?', 'link': 'https://blog.naver.com/yimin3181?Redirect=Log&logNo=221857565192', 'description': '<b>신종 코로나</b> 감염이 중국이 주춤해지면서 현재는 전 세계로 확산되고 있고 특히 이탈리아가 제일... 위의 사진은 코로나 감염의 중증 환자의 폐 ct 사진이다. 이렇게 폐 양측에 병변이 모두 퍼지면 사망하기... ', 'bloggername': '민영일의 건강을 생각하는 블로그', 'bloggerlink': 'https://blog.naver.com/yimin3181', 'postdate': '20200317'}
# {'title': '서울에서 <b>신종 코로나</b>바이러스 감염증(코로나19) 신규 확진자... ', 'link': 'https://blog.naver.com/johnkth?Redirect=Log&logNo=222012383231', 'description': '붕괴를 막을 수 있고 코로나19 사태를 조기에 종식시킬 수 있습니다 투자에 참고하세요 #코로나19확진자 #<b>신종코로나</b>바이러스감염증 #코로나19신규확진자 #깜깜이환자 #감염경로 #자가격리 #무증상감염자', 'bloggername': '현명한 투자자의 바른 길잡이', 'bloggerlink': 'https://blog.naver.com/johnkth', 'postdate': '20200625'}
# {'title': '2월 <b>신종 코로나</b>바이러스 예방수칙 OX퀴즈 이벤트', 'link': 'https://blog.naver.com/kahp_blog?Redirect=Log&logNo=221798638751', 'description': '2월에는 <b>신종 코로나</b>바이러스 확산 방지를 위해 예방수칙 OX퀴즈 이벤트를 진행합니다. 한국건강관리협회와 함께 코로나바이러스 예방수칙도 챙기고 선물도 받아가세요! 참여방법 1. 한국건강관리협회... ', 'bloggername': '건강일기', 'bloggerlink': 'https://blog.naver.com/kahp_blog', 'postdate': '20200210'}
# {'title': '<b>신종 코로나</b> 바이러스 진단키트 개발 현황', 'link': 'https://blog.naver.com/fallfor?Redirect=Log&logNo=221794307174', 'description': '하루가 다르게 코로나 바이러스 상황도 안좋아지고 있기도 하고요. 미세먼지 / 손세정제 / 마스크... <b>신종 코로나</b> 바이러스 진단키트 개발 현황입니다. 티씨엠생명과학은 코넥스 시장에서 거래가 되고 있고... ', 'bloggername': '깐깐꼼꼼 크리스티 언니의 Pick ~!', 'bloggerlink': 'https://blog.naver.com/fallfor', 'postdate': '20200203'}
# {'title': '<b>신종 코로나</b> 바이러스, 큰 유전자 변이는 없어보여', 'link': 'https://creasy.tistory.com/3433', 'description': '3천번 넘는(일부는 7천 건이 넘게 기록되었다고도 하죠) 변이가 기록되고 있는 현 <b>신종코로나</b>... 포스팅 : 계속 변이중인 코로나 바이러스, 백신 개발 난항? 현재 코로나19 바이러스는 A, B, C 세종류로 구분하고... ', 'bloggername': 'Hello World!', 'bloggerlink': 'http://creasy.tistory.com/', 'postdate': '20200524'}
# {'title': '‘<b>신종 코로나</b>와의 전쟁’ 문예작품', 'link': 'http://blog.daum.net/vejex/16136333', 'description': '‘<b>신종 코로나</b>와의 전쟁’ 문예작품 중앙미술학원 작품 선별 교사 작품편 서예 작품 February 13, 2020... 시작된 <b>신종 코로나</b> 감염 사태에 모든 이가 한마음 한뜻으로 뭉쳐 위기를 두려워하지 않고 이겨 승리할 수... ', 'bloggername': 'Photo Album', 'bloggerlink': 'http://blog.daum.net/vejex', 'postdate': '20200213'}
# {'title': '<b>신종 코로나</b>가 뇌졸중 유발할 수 있다?', 'link': 'https://creasy.tistory.com/3424', 'description': '어느 경우든 <b>신종 코로나</b> 바이러스 때문에 발현된다고 보면 될 듯 하니.. 정말 알아갈 수록 경악스런 바이러스인 것 같아요 ㅜㅜ 뇌졸중을 감지하면 무조건 응급처치를 받아야 한다는데 현 코로나 시국으로... ', 'bloggername': 'Hello World!', 'bloggerlink': 'http://creasy.tistory.com/', 'postdate': '20200519'}
# {'title': '<b>신종 코로나</b>바이러스 예방을 위한 수칙', 'link': 'http://blog.daum.net/cn1365/2343', 'description': '<b>신종 코로나</b>바이러스 예방을 위한 수칙 댓글 0 공지사항 2020. 1. 29. <b>신종 코로나</b>바이러스로 걱정이 많습니다. 충청남도는 <b>신종 코로나</b>바이러스 감염증 방역대책반을 구성, 신속하게 대응하고 있습니다. 신종... ', 'bloggername': 'beauty', 'bloggerlink': 'http://blog.daum.net/cn1365', 'postdate': '20200129'}
# {'title': '<b>신종코로나</b>바이러스 증상 및 예방법 방심하지마세요', 'link': 'https://tasty2wins.net/entry/%EC%8B%A0%EC%A2%85%EC%BD%94%EB%A1%9C%EB%82%98%EB%B0%94%EC%9D%B4%EB%9F%AC%EC%8A%A4-%EC%A6%9D%EC%83%81-%EB%B0%8F-%EC%98%88%EB%B0%A9%EB%B2%95-%EB%B0%A9%EC%8B%AC%ED%95%98%EC%A7%80%EB%A7%88%EC%84%B8%EC%9A%94', 'description': '이런분들은 코로나 바이러스에 취약한 분들이라 걸리면 정말 큰일날 수 있으니까요 <b>신종코로나</b>바이러스 증상 및 예방법 그 다음으로는 선별진료소 방문하실때 의료진에게 모든걸 다 말해야 한다는것 입니다... ', 'bloggername': '기쁜일상톡톡', 'bloggerlink': 'https://tasty2wins.net/', 'postdate': '20200324'}

# %% [markdown]
# ### 제목, 링크만 뽑아서 엑셀에 넣기

# %%
import requests
from urllib.parse import urlparse
import pandas as pd

# 검색결과 저장
lc_title = []
lc_link = []

# 함수 선언
def get_api_result(keyword, display, start) :
    url = "https://openapi.naver.com/v1/search/blog?query=" + keyword + "&display=" + str(display) + "&start=" + str(start)
    result = requests.get(urlparse(url).geturl(),
                        headers = {"X-Naver-Client-Id":"frBMA0JHYp1zATqntdUJ",
                                  "X-Naver-Client-Secret":"CzMu_Uce6r"})
    return result.json()

def call_and_print(keyword, page):
    json_obj = get_api_result(keyword, 100, page)
    for item in json_obj['items'] :
        title = item['title'].replace("<b>", "").replace("</b>", "")
        link = item['link']
        
        # 결과를 리스트에 넣기
        lc_title.append(title)
        lc_link.append(link)

# 메인 코드    
keyword="신종코로나"
call_and_print(keyword, 1) # 1-100


# pandas를 이용하여 csv, excel로 저장하기
df = pd.DataFrame()

df['title']=lc_title
df['link']=lc_link

df.to_csv("naver_output.csv",encoding="utf-8-sig", index=False)
df.to_excel("naver_output.xlsx", index=False)

# %% [markdown]
# ### 워드 클라우드 그리기
# #### title만 텍스트 파일로 저장하기

# %%
import requests
from urllib.parse import urlparse
import pandas as pd


def get_api_result(keyword, display, start) :
    url = "https://openapi.naver.com/v1/search/blog?query=" + keyword + "&display=" + str(display) + "&start=" + str(start)
    result = requests.get(urlparse(url).geturl(),
                        headers = {"X-Naver-Client-Id":"frBMA0JHYp1zATqntdUJ",
                                  "X-Naver-Client-Secret":"CzMu_Uce6r"})
    return result.json()

def call_and_print(keyword, page):
    tot_title = ""     #검색결과 저장
    json_obj = get_api_result(keyword, 100, page)
    for item in json_obj['items'] :
        title = item['title'].replace("<b>", "").replace("</b>", "")  

        # 결과를 텍스트로 만들기
        tot_title += title
        
    return tot_title
    
keyword="신종코로나"
title_100 = call_and_print(keyword, 1) # 1-100
print(title_100)
# Out:
# 2020#02 중국 남경 일상(feat. 신종 코로나 바이러스)신종코로나바이러스 국내 확진자 833명, 코로나19가 미치는... 신종코로나보험 신중하게 확인하고 진행해보는 TIP| 우한폐렴 | 신종 코로나바이러스 원인ㆍ증상ㆍ예방법2020.2.3  신종 코로나 바이러스 폐렴과 중국 증시의 급락 개장.수도권 내 신종 코로나바이러스 감염증(코로나19) 집단감염... [투자레터11]신종 코로나바이러스 패닉 셀링 ★ 줍줍 종목은신종 코로나바이러스 예방 자동차 관리법신종코로나바이러스 보험 정보 꼼꼼히 살펴보세요신종코로나19 예방수칙과 대응법에는 어떤 것이 있을까?신종 코로나 바이러스 19를 대처하는 중국정부, 본질을 흐리고... 신종코로나보험 주의사항 잊지 말고 확인해보세요신종코로나 방역 이제는 걱정 없어요아비간 일본에서 코로나19 치료제로 신종플루약 처방신종 코로나 바이러스와 싸우는 로봇우한 폐렴 신종 코로나 바이러스 12번째 확진자 정보 및 예방법신종 코로나 바이러스에 대하여2020.2.1  미국 증시의 이격 조정 그리고 신종 코로나 바이러스신종코로나 보험 정보 자세히 확인하세요신종 코로나(COVID-19)에 감염된 사람이 기르고있는 애완... 신종 코로나바이러스 자가격리 대상자 생활수칙!신종 코로나바이러스 - 메르스와 우한폐렴 비교중국 우한 신종 코로나 바이러스 병
염증(코로나19) 재유행... 신종 코로나 바이러스 과잉 우려신종코로나바이러스는 이렇게 극복합시다신종코로나 미추홀구 확진자동선 및 주의내용.신종 코로나바이러스 감염증과 감기 독감의 차이점 어떤게... 비말차단마스크,덴탈마스크 구입과 신종 코로나열지 마세요! ‘신종 코로나’ 피싱 메일신종 코로나와 대한의사협회신종 코로나바이러스 불안감에따른 우울증신종 코로나 - 유학생 모녀에 대한 정치쇼신종 코로나바이러스 감염증(코로나19) 신규 확진자 수도권... 끝나지 않는 상하이의 신종코로나이탈리아에서는 왜 신종 코로나 사망률이 높은가?서울에서 신종 코로나바이러스 감염증(코로나19) 신규 확진자... 2월 신종 코로나바이러스 예방수칙 OX퀴즈 이벤트신종 코로나 바이러스 진단키트 개발 현황신종 코로나 바이러스, 큰 유전자 변이는 없어보여‘신종 코로나와의 전쟁’ 문예작품신종 코로나가 뇌졸중 유발할 수 있다?신종 코로나바이러스 예방을 위한 수칙신종코로나바이러스 증상 및 예방법 방심하지마세요

# %%
type(title_100)
# Out:
# str

# %%
len(title_100)
# Out:
# 2676

# %% [markdown]
# #### 워드 클라우드 그리기

# %%
# konlpy 설치
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading https://files.pythonhosted.org/packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl (19.4MB)
#      |████████████████████████████████| 19.4MB 49.4MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.6/dist-packages (from konlpy) (1.18.5)
# Collecting beautifulsoup4==4.6.0
#   Downloading https://files.pythonhosted.org/packages/9e/d4/10f46e5cfac773e22707237bfcd51bbffeaf0a576b0a847ec7ab15bd7ace/beautifulsoup4-4.6.0-py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 10.4MB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (4.2.6)
# Collecting JPype1>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/2d/9b/e115101a833605b3c0e6f3a2bc1f285c95aaa1d93ab808314ca1bde63eed/JPype1-0.7.5-cp36-cp36m-manylinux2010_x86_64.whl (3.6MB)
#      |████████████████████████████████| 3.6MB 46.1MB/s
# Collecting tweepy>=3.7.0
#   Downloading https://files.pythonhosted.org/packages/36/1b/2bd38043d22ade352fc3d3902cf30ce0e2f4bf285be3b304a2782a767aec/tweepy-3.8.0-py2.py3-none-any.whl
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/c9/dc/45cdef1b4d119eb96316b3117e6d5708a08029992b2fee2c143c7a0a5cc5/colorama-0.4.3-py2.py3-none-any.whl
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: requests>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.12.0)
# Requirement already satisfied: PySocks>=1.5.7 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.7.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Installing collected packages: beautifulsoup4, JPype1, tweepy, colorama, konlpy
#   Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
#   Found existing installation: tweepy 3.6.0
#     Uninstalling tweepy-3.6.0:
#       Successfully uninstalled tweepy-3.6.0
# Successfully installed JPype1-0.7.5 beautifulsoup4-4.6.0 colorama-0.4.3 konlpy-0.5.2 tweepy-3.8.0

# %% [markdown]
# ## 챠트에서 한글이 깨지면 여기서부터 다시 실행하세요

# %%
# 경고 무시
import warnings
warnings.filterwarnings(action='ignore')

# 모듈 설치
import pandas as pd
import numpy as np

import platform
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['axes.unicode_minus'] = False

from wordcloud import WordCloud, STOPWORDS
from PIL import Image

import requests
from urllib.parse import urlparse
from bs4 import BeautifulSoup 

from nltk import Text
import nltk

# %%
# 그래프에서 한글표현을 위해 폰트를 설치합니다.
# %config InlineBackend.figure_format = 'retina'

# !apt-get -qq -y install fonts-nanum > /dev/null
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)

# 기본 글꼴 변경
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.font_manager._rebuild()
mpl.pyplot.rc('font', family='NanumBarunGothic')

# %%
# 오픈 API로 데이타 수집하기
import requests
from urllib.parse import urlparse
import pandas as pd


def get_api_result(keyword, display, start) :
    #url = "https://openapi.naver.com/v1/search/blog?query=" + keyword + "&display=" + str(display) + "&start=" + str(start)
    url = "https://openapi.naver.com/v1/search/news?query=" + keyword + "&display=" + str(display) + "&start=" + str(start)    
    result = requests.get(urlparse(url).geturl(),
                        headers = {"X-Naver-Client-Id":"frBMA0JHYp1zATqntdUJ",
                                  "X-Naver-Client-Secret":"CzMu_Uce6r"})
    return result.json()

def call_and_print(keyword, page):
    tot_title = ""     #검색결과 저장
    json_obj = get_api_result(keyword, 100, page)
    for item in json_obj['items'] :
총리코로나19, 훨씬 더 일찍 시작해서 훨씬 더 많이 감염시켰다중대본회의서 대화하는 박영선 - 진영 장관구윤철 국무조정실장의 필기구코이카, 영월 옥수수 농가 코로나19 극복 돕는다선별진료소로 변해버린 교회…클럽처럼 ‘고위험 시설’ 지정되나해외유입 2주일 일평균 15.5명…중국외아시아 271명→413명으로 급증[포토] 정세균, 코로나19 대응 중대본 회의 참석[포토] 모두발언하는 정세균 총리[포토] 발언하는 정세균 총리[포토] 코로나19 대응 중대본 회의경남은행, 6.25전쟁 현충시설 환경정화활동…언택트 사회공헌 활발[포토] 정세균, 중대본 회의 주재[포토] 중대본 회의 주재하는 정세균 총리휴가 복귀 철원 장병·이태원 방문 대학생 확진자 잇따라 퇴원중대본회의 참석하는 유은혜 부총리와 박능후 장관중대본회의 참석하는 유은혜 부총리와 박능후 장관불법사금융 이자 6%로 제한…벌금 최고 1억으로 강화코로나19 신규 확진 62명 중 지역발생 40명 해외유입 22명…총 1만2715명일요 법회 열린 조계사일요 법회 열린 조계사중대본회의 참석하는 유은혜 부총리코로나 시대의 승자 'BBIG7'…새 주도주로 자리잡았다조계사 대웅전 앞에서 법회 참여하는 신도들일요 법회 참석한 불교 신자들일요 법회 열린 조계사일요 법회 열린 조계사일요 법회 참석한 불교 신자들2분기 고용 실적 '역대 최저'…코로나19 직격탄중대본 참석한 김현미 장관7개월만에 출전한 앤디 머리, 영국 테니스 이벤트 대회서 에번스에게 져 4강 ...조계사 대웅전 앞에서 법회 참여일요 법회 열린 조계사계룡세계군문화엑스포 내년 10월 1일 연다조계사 대웅전 앞에서 법회 참여아이엠헬스케어, &quot;바이오센서 기반 코로나19 진단키트 개발&quot;중대본 참석하는 정세균 총리'주말·휴일 고비 못 넘긴 대전'…이틀 사이 코로나19 확진 7명[이번주 환율] 방향성예측 어려운 원·달러환율...당분간 보합 전망 우세중대본 참석하는 정세균 총리신도만 수천명씩...수도권 ‘교회발 집단감염’ 일파만파세징야, 브라질 매체와 인터뷰서 ‘韓 귀화’ 의지 표명[2보] 수원·안양 교회 관련 확진자 늘어…교회 관련 조사자만 2600명중대본 참석하는 정세균 총리&quot;주식도 달러도 분할 매수…변동성 대비를&quot;영광사랑카드 10% 우대 혜택 연말까지 연장전용기 의원 ‘자영업자 구하기’ 행보…“현실 고민 잘 알아…해법 마련에 최...`선거 회계부정 의혹` 정정순 의원 &quot;불법·부정 지시한 적 없어&quot;"

# %%
# 형태소 분석기
from konlpy.tag import Okt
t = Okt()

# %%
# 명사만 추출 - 글자길이가 2이상인 단어만 추출
tokens_ko = t.nouns(title_100) 
tokens_ko = [ ko for ko in tokens_ko if len(ko) > 1 ]
tokens_ko
# Out:
# ['동행',
#  '주말',
#  '행세',
#  '주말',
#  '유통',
#  '활기',
#  '코로나',
#  '이후',
#  '매출',
#  '증가',
#  '최대',
#  '이효리',
#  '개월',
#  '빌딩',
#  '지금',
#  '가격',
#  '성공',
#  '투자',
#  '한남동',
#  '광주',
#  '코로나',
#  '접촉',
#  '음성',
#  '판정',
#  '검사',
#  '중인',
#  '천시',
#  '이하',
#  '청년',
#  '고용',
#  '기업',
#  '개월치',
#  '월급',
#  '교육비',
#  '비상',
#  '트럼프',
#  '행정부',
#  '코로나',
#  '가동',
#  '민주당',
#  '추경',
#  '통합',
#  '압박',
#  '천지',
#  '포토',
#  '대한민국',
#  '동행',
#  '교회',
#  '집단',
#  '감염',
#  '확산',
#  '수원',
#  '대형',
#  '교회',
#  '코로나',
#  '확진',
#  '종합',
#  '이용섭',
#  '광주시',
#  '방역',
#  '시민',
#  '협조',
#  '천지',
#  '포토',
#  '대한민국',
#  '동행',
#  '바젤',
#  '최종',
#  '지주',
#  '조기',
#  '시행',
#  '군포',
#  '주영광',
#  '교회',
#  '신도',
#  '추가',
#  '확진',
#  '천지',
#  '포토',
#  '대한민국',
#  '동행',
#  '주말',
#  '종합',
#  '안양',
#  '주영광',
#  '교회',
#  '비롯',
#  '수원',
#  '중앙',
#  '침례교회',
#  '관악',
#  '왕성',
#  '교회',
#  '연일',
#  '확진',
#  '서울',
#  '진자',
#  '경북',
#  '수준',
#  '근접',
#  '유은혜',
#  '교육',
#  '장관',
#  '회의',
#  '온라인',
#  '개학',
#  '순차',
#  '등교',
#  '경험',
#  '공유',
#  '하반기',
#  '비대',
#  '장주',
#  '상승세',
#  '지속',
#  '그래픽',
#  '경제',
#  '성장',
#  '전망',
#  '미국',
#  '경제',
#  '이후',
#  '회복',
#  '역성',
#  '불가피',
#  '삼성',
#  '에너지',
#  '효율',
#  '라인업',
#  '출시',
#  '유망',
#  '해외',
#  '주식',
#  '마이크로소프트',
#  '순위',
#  '교회',
#  '코로나',
#  '감염',
#  '확산',
#  '지속',
#  '위험',
#  '시설',
#  '지정',
#  '검토',
#  '서울시',
#  '자영',
#  '업자',
#  '생존',
#  '자금',
#  '수급',
#  '절반',
#  '임대료',
#  '사용',
#  '청춘',
#  '잠정',
#  '기획전',
#  '히어',
#  '철원',
#  '장병',
#  '진자',
#  '완치',
#  '퇴원',
#  '송영길',
#  '아베',
#  '한국',
#  '참가',
#  '반대',
#  '행태',
#  '혐한',
#  '정치',
#  '변동성',
#  '서도',
#  '시장',
#  '대비',
#  '초과',
#  '수익',
#  '모주',
#  '청약',
#  '펀드',
#  '관심',
#  '코로나',
#  '유행',
#  '공포',
#  '제조업체',
#  '최저',
#  '코로나',
#  '지역',
#  '감염',
#  '광주',
#  '전남',
#  '확산',
#  '국방부',
#  '청사',
#  '어린이집',
#  '원아',
#  '교사',
#  '감염',
#  '원아',
#  '검사',
#  '불법',
#  '사금융',
#  '이자',
#  '제한',
#  '벌금',
#  '최고',
#  '강화',
#  '수원',
#  '중앙',
#  '침례교회',
#  '코로나',
#  '확진',
#  '왕성',
#  '교회',
#  '백신',
#  '진단',
#  '키트',
#  '유망',
#  '그래핀',
#  '개발',
#  '김부겸',
#  '수백만',
#  '국민',
#  '생계',
#  '추경안',
#  '밥값',
#  '코로나',
#  '혈장',
#  '치료',
#  '연내',
#  '내년',
#  '항체',
#  '치료',
#  '출시',
#  '기대',
#  '정통부',
#  '공기청정기',
#  '바이러스',
#  '필터',
#  '연구',
#  '혁신',
#  '제품',
#  '광주',
#  '정보',
#  '문화',
#  '산업',
#  '진흥',
#  '덕분',
#  '린지',
#  '동참',
#  '원피스',
#  '애니',
#  '방송',
#  '재개',
#  '루피',
#  '탈주',
#  '결말',
#  '코로나',
#  '원금',
#  '어디',
#  '중소기업',
#  '상반기',
#  '베스트',
#  '파트너',
#  '추천',
#  '하반기',
#  '투자',
#  '전략',
#  '윤철',
#  '국무조정실장',
#  '필기구',
#  '코로나',
#  '주요',
#  '확산',
#  '방문',
#  '감염',
#  '광주',
#  '전남',
#  '확진',
#  '미스테리',
#  '광주시',
#  '코로나',
#  '지역',
#  '사회',
#  '추가',
#  '확산',
#  '대비',
#  '송영길',
#  '아베',
#  '확대',
#  '회의',
#  '참여',
#  '반대',
#  '내용',
#  '혐한',
#  '정책',
#  '글로벌',
#  '델타항공',
#  '조종사',
#  '임시',
#  '해고',
#  '경고',
#  '코로나',
#  '진자',
#  '명대',
#  '서울',
#  '확산',
#  '포토',
#  '대본',
#  '회의',
#  '참석',
#  '유은혜',
#  '부총리',
#  '홍콩',
#  '내달',
#  '주권',
#  '반환',
#  '기념',
#  '집회',
#  '불허',
#  '처음',
#  '이용섭',
#  '광주시',
#  '방역',
#  '시민',
#  '협조',
#  '포토',
#  '박능후',
#  '대본',
#  '회의',
#  '참석',
#  '포토',
#  '발언',
#  '정세균',
#  '국무총리',
#  '포토',
#  '코로나',
#  '대응',
#  '대본',
#  '회의',
#  '주재',
#  '정세균',
#  '총리',
#  '코로나',
#  '일찍',
#  '시작',
#  '감염',
#  '중대',
#  '본회의',
#  '대화',
#  '박영선',
#  '진영',
#  '장관',
#  '윤철',
#  '국무조정실장',
#  '필기구',
#  '코이카',
#  '영월',
#  '옥수수',
#  '농가',
#  '코로나',
#  '극복',
#  '선별',
#  '진료',
#  '소로',
#  '교회',
#  '클럽',
#  '위험',
#  '시설',
#  '지정',
#  '해외',
#  '유입',
#  '주일',
#  '평균',
#  '중국',
#  '아시아',
#  '급증',
#  '포토',
#  '정세균',
#  '코로나',
#  '대응',
#  '대본',
#  '회의',
#  '참석',
#  '포토',
#  '발언',
#  '정세균',
#  '총리',
#  '포토',
#  '발언',
#  '정세균',
#  '총리',
#  '포토',
#  '코로나',
#  '대응',
#  '대본',
#  '회의',
#  '경남',
#  '은행',
#  '전쟁',
#  '현충시설',
#  '환경',
#  '정화',
#  '활동',
#  '언택트',
#  '사회',
#  '공헌',
#  '활발',
#  '포토',
#  '정세균',
#  '대본',
#  '회의',
#  '주재',
#  '포토',
#  '대본',
#  '회의',
#  '주재',
#  '정세균',
#  '총리',
#  '휴가',
#  '복귀',
#  '철원',
#  '장병',
#  '이태원',
#  '방문',
#  '대학생',
#  '진자',
#  '퇴원',
#  '중대',
#  '본회의',
#  '참석',
#  '유은혜',
#  '부총리',
#  '박능후',
#  '장관',
#  '중대',
#  '본회의',
#  '참석',
#  '유은혜',
#  '부총리',
#  '박능후',
#  '장관',
#  '불법',
#  '사금융',
#  '이자',
#  '제한',
#  '벌금',
#  '최고',
#  '강화',
#  '코로나',
#  '신규',
#  '확진',
#  '지역',
#  '발생',
#  '해외',
#  '유입',
#  '명일',
#  '법회',
#  '조계사',
#  '일요',
#  '법회',
#  '조계사',
#  '중대',
#  '본회의',
#  '참석',
#  '유은혜',
#  '부총리',
#  '코로나',
#  '시대',
#  '승자',
#  '도주',
#  '자리',
#  '조계사',
#  '대웅전',
#  '법회',
#  '참여',
#  '신도',
#  '일요',
#  '법회',
#  '참석',
#  '불교',
#  '신자',
#  '일요',
#  '법회',
#  '조계사',
#  '일요',
#  '법회',
#  '조계사',
#  '일요',
#  '법회',
#  '참석',
#  '불교',
#  '신자',
#  '고용',
#  '실적',
#  '역대',
#  '최저',
#  '코로나',
#  '격탄',
#  '대본',
#  '참석',
#  '김현미',
#  '장관',
#  '개월',
#  '출전',
#  '앤디',
#  '머리',
#  '영국',
#  '테니스',
#  '이벤트',
#  '대회',
#  '에번스',
#  '조계사',
#  '대웅전',
#  '법회',
#  '참여',
#  '일요',
#  '법회',
#  '조계사',
#  '계룡',
#  '세계',
#  '문화',
#  '엑스포',
#  '내년',
#  '조계사',
#  '대웅전',
#  '법회',
#  '참여',
#  '아이엠',
#  '스케',
#  '바이오',
#  '센서',
#  '기반',
#  '코로나',
#  '진단',
#  '키트',
#  '개발',
#  '대본',
#  '참석',
#  '정세균',
#  '총리',
#  '주말',
#  '휴일',
#  '고비',
#  '대전',
#  '이틀',
#  '사이',
#  '코로나',
#  '확진',
#  '이번',
#  '환율',
#  '방향성',
#  '예측',
#  '달러',
#  '환율',
#  '당분간',
#  '보합',
#  '전망',
#  '우세',
#  '대본',
#  '참석',
#  '정세균',
#  '총리',
#  '신도',
#  '천명',
#  '수도권',
#  '교회',
#  '집단',
#  '감염',
#  '일파',
#  '브라질',
#  '매체',
#  '인터뷰',
#  '귀화',
#  '의지',
#  '표명',
#  '수원',
#  '안양',
#  '교회',
#  '관련',
#  '진자',
#  '교회',
#  '관련',
#  '조사',
#  '자만',
#  '명중',
#  '대본',
#  '참석',
#  '정세균',
#  '총리',
#  '주식',
#  '달러',
#  '분할',
#  '매수',
#  '변동성',
#  '대비',
#  '영광',
#  '사랑',
#  '카드',
#  '우대',
#  '혜택',
#  '연말',
#  '연장전',
#  '용기',
#  '의원',
#  '자영',
#  '업자',
#  '행보',
#  '현실',
#  '고민',
#  '해법',
#  '마련',
#  '선거',
#  '회계부정',
#  '의혹',
#  '정정',
#  '의원',
#  '불법',
#  '부정',
#  '지시']

# %%
# nltk
ko = nltk.Text(tokens_ko, name='신종코로나')
ko.vocab().most_common(100)
# Out:
# [('코로나', 23),
#  ('포토', 13),
#  ('참석', 12),
#  ('교회', 11),
#  ('대본', 11),
#  ('정세균', 10),
#  ('법회', 10),
#  ('회의', 9),
#  ('조계사', 8),
#  ('감염', 7),
#  ('확진', 7),
#  ('총리', 7),
#  ('확산', 6),
#  ('일요', 6),
#  ('진자', 5),
#  ('유은혜', 5),
#  ('장관', 5),
#  ('동행', 4),
#  ('주말', 4),
#  ('광주', 4),
#  ('수원', 4),
#  ('참여', 4),
#  ('부총리', 4),
#  ('중대', 4),
#  ('본회의', 4),
#  ('천지', 3),
#  ('대한민국', 3),
#  ('광주시', 3),
#  ('신도', 3),
#  ('해외', 3),
#  ('대비', 3),
#  ('지역', 3),
#  ('불법', 3),
#  ('박능후', 3),
#  ('발언', 3),
#  ('대응', 3),
#  ('주재', 3),
#  ('대웅전', 3),
#  ('이후', 2),
#  ('개월', 2),
#  ('투자', 2),
#  ('검사', 2),
#  ('고용', 2),
#  ('집단', 2),
#  ('종합', 2),
#  ('이용섭', 2),
#  ('방역', 2),
#  ('시민', 2),
#  ('협조', 2),
#  ('주영광', 2),
#  ('추가', 2),
#  ('안양', 2),
#  ('중앙', 2),
#  ('침례교회', 2),
#  ('왕성', 2),
#  ('서울', 2),
#  ('하반기', 2),
#  ('지속', 2),
#  ('경제', 2),
#  ('전망', 2),
#  ('출시', 2),
#  ('유망', 2),
#  ('주식', 2),
#  ('위험', 2),
#  ('시설', 2),
#  ('지정', 2),
#  ('자영', 2),
#  ('업자', 2),
#  ('철원', 2),
#  ('장병', 2),
#  ('퇴원', 2),
#  ('송영길', 2),
#  ('아베', 2),
#  ('반대', 2),
#  ('혐한', 2),
#  ('변동성', 2),
#  ('최저', 2),
#  ('전남', 2),
#  ('원아', 2),
#  ('사금융', 2),
#  ('이자', 2),
#  ('제한', 2),
#  ('벌금', 2),
#  ('최고', 2),
#  ('강화', 2),
#  ('진단', 2),
#  ('키트', 2),
#  ('개발', 2),
#  ('치료', 2),
#  ('내년', 2),
#  ('문화', 2),
#  ('윤철', 2),
#  ('국무조정실장', 2),
#  ('필기구', 2),
#  ('방문', 2),
#  ('사회', 2),
#  ('유입', 2),
#  ('불교', 2),
#  ('신자', 2),
#  ('환율', 2)]

# %%
ko.similar('신규')

# %%
#단어빈도로 챠트 그리기
plt.figure(figsize=(10,6))
ko.plot(50)
plt.show()

# %%
data = ko.vocab().most_common(50)

wordcloud = WordCloud(font_path='/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf',
                      relative_scaling = 0.2,
                      #stopwords=STOPWORDS,
                      background_color='white',
                      ).generate_from_frequencies(dict(data))
plt.figure(figsize=(10,7))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# ### 이미지 반영한 워드클라우드

# %% [markdown]
# 그림 파일 불러오기 : corona.PNG

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-6050bba9-4650-48f3-b6e9-284677c181a0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6050bba9-4650-48f3-b6e9-284677c181a0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving corona.PNG to corona (3).PNG
# User uploaded file "corona.PNG" with length 161707 bytes

# %% [markdown]
# 워드 클라우드

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
from wordcloud import ImageColorGenerator

mask = np.array(Image.open('corona.PNG'))
image_colors = ImageColorGenerator(mask)

# %%
data = ko.vocab().most_common(200)

wordcloud = WordCloud(font_path='/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf', 
                      relative_scaling = 0.1, mask=mask,
               background_color = 'white',
               min_font_size=1,
               max_font_size=100).generate_from_frequencies(dict(data))

default_colors = wordcloud.to_array()

plt.figure(figsize=(10,10))
plt.imshow(wordcloud.recolor(color_func=image_colors), interpolation='bilinear')
plt.axis('off')
plt.show()
